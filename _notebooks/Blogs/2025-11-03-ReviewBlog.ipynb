# %% [raw]
# ---
# title: "Final Review Blog"
# description: "Review of Trimester 1"
# layout: post
# permalink: /blog/retrospect
# author: Akshara Shankar
# ---

# %% [markdown]
# Test Corrections:
# 1. The answer is B because the code segment assigns the initial value of the first to temp then assigns the intial value of second to first. The initial value of first which has been sotred in temp is then assigned to second. Therefor, the intial values of first and second have been interchanged.
# 3. The answer is C because if data measurements need to be taken from many locations, it would be beneficial to have participants from around the world collect the data
# 10. The code in Option B is correct because it describes how the circles are positioned. It starts the first circle right where it belongs, at the center (3, 6). Then, for the next two circles, it shifts the center 2 units to the right (that's the xPos + 2 part) AND 2 units down (that's the yPos - 2 part). This movement correctly plots the centers at (5, 4) and then (7, 2), tracing the figure's diagonal pattern.
# 15. The answer is option C because You can only connect a new device to the internet because it gets assigned an IP address.
# 16. The answer is option D becuase If the album was purchased and downloaded through a licensed music store, the user will not be in violation of the DMCA
# 17. The answer is option D, since you need to address the lack of skills, devices, and internet access to completely close the gap, all three actions (I, II, and III) are necessary.
# 22. The answer is option B as the Boolean expression evaluates to true when counter (the number of temperatures greater than or equal to 90) is greater than 50% of total (the number of entries in the list).
# 23. The answer is option B. If there's only one way to get from one point to another, you can't have redundancy. For example, since the path from P to S has to go through R and Q, if any one of those pieces breaks, the connection is completely lost.
# 24. The correct answer is C as this process is lossless because you can always get the original message back perfectly. For example, if you change '111' to '11' and '000' to '00', you can just swap them back later to restore the exact starting string.
# 28. The correct answer is D as using 8 bits will only allow for up to 256 characters, (2^8 = 256)
#
# 29. Option A is correct as With these inputs, the AND gate will produce an output of false and the first OR gate will produce an output of false. Since both inputs to the second OR gate will be false, the circuit will have an output of false
# 32. Option A is correct as the Xs indicating participants who are interested in the application, are clustered toward the top of the graph.This indicates that participants who read more were generally more likely to say they are interested in the application.
# 34. Option D is correct as the number of predators is initialized at the beginning of the program but is never updated
# 35. Correct answer is D as Creative Commons licenses can be used by creators of digital music to specify how the samples can be used by others. A no-rights-reserved license allows others to freely make use of the samples
# 36. option B is correct because the fixed number of bits used to represent real numbers (as floating-point numbers) limits the range of floating-point values.
# 38. Option C is correct. The expression count MOD 10 = 0 evaluates to true when count is a multiple of 10, and so this
# code segment sets cost to 0 under the appropriate conditions.
# 39. Option A is correct as open standards and protocols are used to prescribe the format of data sent over the Internet. This allows all connected hardware and software to communicate in a standard way.
# 41. Option B is correct.  This expression uses the Max procedure to replace the midterm score with the higher of the two scores. The selected value is then added to the final exam score and assigned to adjustedTotal.
# 43. Option A is correct as the pattern in the table appears to indicate that there are n squared steps for a list containing n items. This number of steps is a polynomial and therefore the algorithm runs in reasonable time
# 47. Option D is correct, because in public cryptography, a message is encrypted with a recipient’s public key and decrypted with the recipient’s private key
# 51. Option B is correct as this is an example of symmetric encryption because the secret key is used for both encryption and decryption of messages
# 54. Option D is correct. The procedures square and cube are each used to determine a power of n. A generalization of this procedure
# is Power(n,m) which calculates n raised to the m power.
# 55. Option D is correct. The expression (response = 'y') AND, open(response = 'yes') always evaluates to false because it is not possible for the variable response to be equal to both 'y' and  "yes", close quotation. Therefore, the procedure will always
# return false.
# 57. Option B is correct because this expression concatenates the first two letters of "Harp" with the last three letters "puppy" resulting in "Happy"
# 59. Option B is correct as using lossy compression will provide only an estimate of the original video data. The full-quality original versions of the videos will be lost if lossy compression is used.
# 61. Option A is correct because it is possible to create a single list of student names, sorted by last name. Both data formats provide the first and last names of each student.
# Option B is also correct as it is possible to determine the average number of days students are absent. Both data formats provide the number of absences for each student.
# 62. Option C is correct As any user has the ability to edit articles, there will be many opportunities for people with different perspectives to contribute.
# Option D is also correct as the online encyclopedia can be edited at any time, so it is easy to create or update articles as new information becomes available.
# 63. Option B is correct. If count is set to 0 repeatedly inside the loop, it will not provide an accurate count of the number of prime
# numbers in the list. Option D is correct since If count is incremented outside the IF statement, it will increase for all entries in the list instead of just the prime entries.
# 64. Option B is correct because cloud computing encourages new ways to communicate and collaborate, allowing users to share files and tools easily. Option C is correct as cloud computing sites must consider security concerns in order to protect their users’ private data.
# 65. Option B i s correct If y is negative, then the condition count equals y will never be met since count begins at 0 and repeatedly increases. Option D is also correct because If y is negative, then the condition count equals y will never be met since count begins at 0 and repeatedly increases.
# 66. Option C is correct. The procedure returns the first number it encounters that is less than the first number in the list. For the list [30, 40, 20, 10], the procedure returns 20, which is not the least value in the list. Option D is also correct as the procedure returns the first number it encounters that is less than the first number in the list. For the list [40, 30, 20, 10], the procedure returns 30, which is not the least value in the list.

# %% [markdown]
# Photos from Night at the Museum
# <img width="768" height="1024" alt="Image" src="https://github.com/user-attachments/assets/f3de2ee7-ebbb-4854-aef2-e747d96c58b2" />

# %% [markdown]
# <img width="768" height="1024" alt="Image" src="https://github.com/user-attachments/assets/941c8987-c4d0-4c61-9423-d1f8244efd3c" />

# %% [markdown]
# <img width="768" height="1024" alt="Image" src="https://github.com/user-attachments/assets/de0c676d-4d55-419b-9557-a4c776bd4523" />

# %% [markdown]
# <img width="768" height="1024" alt="Image" src="https://github.com/user-attachments/assets/c340d57c-7e85-4c81-9ccc-30bc4062e585" />

# %% [markdown]
# ## How I grade myself at the start of Trimester 1:
#
# | Skill | Mastered (Y/N) | Self Rank (1-5) | Peer Rank (1-5) | Teacher Rank (1-5) | Average | Notes/Evidence |
# | :--- | :---: | :---: | :---: | :---: | :---: | :--- |
# | **🎯 Core Behaviors** | | | | | | |
# | Attendance | ✅ | 5 | 5 | | | Consistently attended all classes and meetings on time except for when sick. |
# | Work Habits | ✅ | 4 | 5 | | | Completed tasks efficiently, though sometimes not as much as stronger members. |
# | Behavior | ✅ | 5 | 5 | | | Maintained a positive and respectful attitude in class. I was always excited to work during class. |
# | Timeliness | ✅ | 5 | 5 | | | Turned in all assignments on time. |
# | **💻 Technical Skills** | | | 3 | 3 | | I don’t know a lot of code |
# | Tech/Cyber Sense | ✅ | 4 | 4 | | | Demonstrated understanding of safe and responsible tech use. |
# | Tech/Cyber Talk | ✅ | 4 | 4 | | | Communicated tech concepts with peers. |
# | Tech Growth | ✅ | 3 | 3 | | | Showing progress in coding and technical projects. |
# | **🤝 Collaboration** | | 5 | 5 | | | Very excited to collaborate with others. |
# | Advocacy | | 4 | 4 | | | I support my team ideas and suggest some of my own. |
# | Communication & Collab | ✅ | 4 | 5 | | | Work well in teams and shares ideas my effectively, but could be more precise. |
# | **🎨 Professional Skills** | | | | | | |
# | Integrity | ✅ | 5 | 5 | | | Consistently honest and ethical in work. |
# | Organization | ✅ | 5 | 5 | | | Works hard to stay organized |
# | **📈 TOTALS** | | | | | | |
# | **🎯 AVERAGE SCORE** | | | | | | |

# %% [markdown]
# ## How I grade myself at end of Trimester 1:
#
# | Skill | Mastered (Y/N) | Self Rank (1-5) | Peer Rank (1-5) | Teacher Rank (1-5) | Average | Notes/Evidence |
# | :--- | :---: | :---: | :---: | :---: | :---: | :--- |
# | **🎯 Core Behaviors** | | | | | | |
# | Attendance | ✅ | 5 | 4 | | | Not many absences. |
# | Work Habits | ✅ | 5 | 5 | | | I try my hardest to complete the work above and beyond to the best of my ability. |
# | Behavior | ✅ | 5 | 5 | | | I come to class with an excited and positive attitude, and respect others. |
# | Timeliness | | 5 | 5 | | | I complete my work on time, and use my time wisely in class. |
# | **💻 Technical Skills** | | | 4 | 4 | | My technical skills have improved a lot since the start of the year as I have learned a lot more new things. |
# | Tech/Cyber Sense | ✅ | 4.5 | 4.5 | | | My cyber sense has improved a lot compared to sprint 1; I can fix and understand my code better now, though I am not perfect. |
# | Tech/Cyber Talk | ✅ | 4 | 4 | | | Need to improve clarity and confidence when explaining tech concepts. |
# | Tech Growth | ✅ | 5 | 5 | | | I have improved a lot since the start of the year and I have learned how to fix my own technical errors. |
# | **🤝 Collaboration** | | | 5 | 5 | | I work with my peers and respect their ideas. |
# | Advocacy | ✅ | 5 | 5 | | | Speaking up for my ideas and supporting team discussions has improved. |
# | Communication & Collab | ✅ | 5 | 5 | | | Works effectively with peers and shares ideas clearly. |
# | **🎨 Professional Skills** | | | | | | |
# | Integrity | ✅ | 5 | 5 | | | Consistently honest and ethical in my work. |
# | Organization | ✅ | 5 | 5 | | | I keep my work very organized and work hard to keep it that way. |
# | **📈 TOTALS** | | | | | | |
# | **🎯 AVERAGE SCORE** | | | | | | |

# %% [markdown]
# title: Open Coding
# description: "Class of 2026"
# owner_name: John Mortensen
# github_username: jm1021
# github_repo: "student"
# baseurl: "/student"
# future: true
# remote_theme: jekyll/minima
# minima:
#   skin: dark
#   social_links:
#     - { platform: github, user_url: "user_url_removed" }
#     - { platform: x, user_url: "user_url_removed" }
#     - { platform: youtube, user_url: "user_url_removed" }
# plugins:
#   - jekyll-remote-theme
#   - jekyll-include-cache
# header_pages:
#   - navigation/blog.md
#   - navigation/search.md
#   - navigation/about.md
#   - navigation/logintoolkit.md

# %% [markdown]
# ## How have I improved through the trimester:
# Over the course of Trimester 1, I have improved significantly in both my technical and collaborative skills. At the beginning of the trimester, I struggled with coding and often felt unsure about how to solve technical problems. However, by the end of the trimester, my technical skills and understanding of code improved a lot—I can now fix my own errors and understand coding concepts much better. My Tech Growth score increased from a 3 to a 5, showing how much progress I made through consistent effort and learning. I also improved in communication and advocacy, becoming more confident in sharing my ideas and supporting my teammates during discussions. My strong work habits, organization, and positive attitude remained consistent throughout, as I continued to complete all assignments on time and stay focused in class. Overall, I grew not just in skill, but also in confidence and teamwork, making me a stronger and more independent learner than I was at the start of the trimester.

# %% [markdown]
# # ⚙️ Configuration Settings
#
# * **title:** Open Coding
# * **description:** "Class of 2026"
# * **owner_name:** John Mortensen
# * **github_username:** jm1021
# * **github_repo:** "student"
# * **baseurl:** "/student"
# * **future:** true
# * **remote_theme:** jekyll/minima
# * **minima:**
#     * **skin:** dark
#     * **social_links:**
#         * platform: github, user_url: "user_url_removed"
#         * platform: x, user_url: "user_url_removed"
#         * platform: youtube, user_url: "user_url_removed"
# * **plugins:**
#     * jekyll-remote-theme
#     * jekyll-include-cache
# * **header_pages:**
#     * navigation/blog.md
#     * navigation/search.md
#     * navigation/about.md
#     * navigation/logintoolkit.md

# %% [markdown]
# **Compare yourself to the beginning of the year:**
# At the beginning of the year, I was still figuring out the basics of how everything in computer science connected — from GitHub to Python to web development. Now, I’ve grown a lot more confident in my coding abilities and understanding of how different parts of a project come together. I’ve learned how to debug effectively, think through problems logically, and use new tools without being afraid to experiment.
#
# **Remember key things from 3 sprints (Tools, Fundamentals of JavaScript/Python, West Coast Travel or Digital Famine):**
# **Tools Sprint:** This sprint helped me get comfortable with GitHub, VS Code, and deployment setups. I learned how to manage repositories, push and pull commits, and keep track of code versions.
# **Fundamentals of JavaScript/Python:** I built a stronger foundation in both languages — learning about variables, loops, conditionals, and functions. It also helped me understand how Python is great for backend logic and how JavaScript makes web pages interactive.
# **West Coast Travel / Digital Famine:** This sprint was really fun because it let me apply what I learned to an actual project. I liked how it mixed creativity with technical skills, and it gave me experience working on something that felt real and meaningful.
#
# **How N@tM went:**
# N@tM was very successful! I really enjoyed teaching others, learning from different projects, and exploring so many unique concepts. It was amazing to see how everyone’s projects reflected their interests and creativity. I also received some great comments from people who liked how I explained my project clearly and how it showed real technical depth.
#
# **What I want to do next on the project:**
# If I had more time, I’d like to make the project even more interactive and add features that make it more dynamic. I’d also like to improve the overall design and maybe connect it to a database to handle user data or real-time updates.
#
# **What I want to learn next in CompSci:**
# Next, I want to learn more about APIs, AI, and data science. I’m really interested in how coding can be used to analyze real-world data, automate processes, and make predictions. I’d also like to dive deeper into backend development and strengthen my full-stack skills.
#
# **Analytics review:**
# My analytics show steady improvement across all sprints. I’ve gotten better at writing cleaner code, making fewer syntax errors, and completing tasks faster. I can also see that my problem-solving skills have improved a lot since the start of the year.
#
# **MCQ review, score, correction, and approach:**
# My MCQ scores improved after I started slowing down and reading each question carefully. I learned to trace the logic step by step instead of rushing. When I got a question wrong, I reviewed the concept immediately, which helped me understand why the correct answer worked.
#
# **Something Cool I want to share:**
# My favorite thing to code is making interactive games and I want to get better at it.

# %% [markdown]
# ## Data analytics

# %% [markdown]
# <img width="1748" height="1332" alt="Image" src="https://github.com/user-attachments/assets/aed19f99-c056-4cb1-9756-cdd4c3f1423e" />

# %% [markdown]
# ## Peppa Pig Maze

# %% [markdown]
# My team and I created a very simple Peppa Pig-themed maze in computer science. The maze itself was straightforward, but its main purpose was to guide players to different blogs that taught lessons. We worked together to design the pathways and make sure that navigating the maze would lead correctly to each blog, testing our code along the way. This project helped me practice basic coding, problem-solving, and teamwork, even though the maze was simple, because we had to make sure it functioned as intended.

# %% [markdown]
# ## Night in the Museum AI Blog+MC

# %% [markdown]
# For the Night in the Museum project my team mate and I worked together to create a blog about different types of AI. We included a multiple-choice section to make the content interactive and tried to engage readers with questions and examples. While the blog was informative, we realized that it could be more engaging, and we want to improve by adding more interactive elements or visuals to make learning about AI more fun and memorable for readers.

# %% [markdown]
# ## Picutes of N@TM (The part I worked on)

# %% [markdown]
# <img width="1388" height="1510" alt="Image" src="https://github.com/user-attachments/assets/e03564cb-5815-42f6-8018-b6704dc0832b" />

# %% [markdown]
# <img width="1414" height="1354" alt="Image" src="https://github.com/user-attachments/assets/77925888-e6b8-4985-97d0-b97299592208" />

# %% [markdown]
# <img width="1362" height="1496" alt="Image" src="https://github.com/user-attachments/assets/1e90f819-c4b0-4fed-80e3-b2bcd87cb9cb" />

# %% [markdown]
# <img width="1772" height="1512" alt="Image" src="https://github.com/user-attachments/assets/d0a593cc-4d21-4b77-af88-4375f614437e" />

# %% [markdown]
# ## Future Goals

# %% [markdown]
# - My goal is to master the core concepts of algorithms, data, and programming and use that knowledge to develop a creative computational solution while critically analyzing the societal impact of my work.
