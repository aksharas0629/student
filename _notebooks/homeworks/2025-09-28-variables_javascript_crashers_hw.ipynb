# %% [raw]
# ---
# layout: post
# title: "3.1 Variables & Assignments hacks"
# categories: [Programming Fundamentals, Tutorial]
# tags: [python, javascript, variables, assignment, beginner]
# description: Apply your understanding of Variables & Assignments with these hacks
# author: Aditya Srivastava, Laya Balaji
# permalink: /javascript/variables/crashers-hw
# ---

# %% [markdown]
# # 🐷 Peppa Maze Variables & Assignments Hacks
# Welcome to the Peppa Maze hacks! These challenges will test your understanding of variables, assignments, and logic in Javascript. Read each task, then write or modify code to solve it.

# %% [markdown]
# ## Hack 1: JavaScript - Variable Assignment, Naming, and Operators
# Create variables for Peppa's name, score, and level using good JavaScript naming conventions. Assign initial values, then use operators to update score (add 10) and level (multiply by 2). Print all results.

# %%
# Q1 (Exponents)
# A cube has a side length of 4 units. What is its volume?
side_length = 4
volume = side_length ** 3
print("The volume of the cube is:", volume, "cubic units")

# Q2 (PEMDAS)
# Evaluate the expression: (12+8)/2 + (3^2)
# Note: In Python, ^ is bitwise XOR, so we use ** for exponentiation

result = (12 + 8) / 2 + (3 ** 2)
print("The result of the expression is:", result)

# Q3 (Algorithm)
# Define variables and perform operations on them
a = 10
b = 5
c = 2

# Perform arithmetic operations
sum_result = a + b
product_result = b * c
difference_result = a - c
division_result = a / b
power_result = b ** c

# Display the results
print("Sum:", sum_result)
print("Product:", product_result)
print("Difference:", difference_result)
print("Division:", division_result)
print("Power:", power_result)

## Hack 1: JavaScript - Variable Assignment, Naming, and Operators
# %%javascript
// Create variables for Peppa's name, score, and level
let peppaName = "Peppa";
let peppaScore = 0;
let peppaLevel = 1;

// Update score and level using operators
peppaScore += 10; // add 10 to score
peppaLevel *= 2;  // multiply level by 2

// Print results
console.log("Name:", peppaName);
console.log("Updated Score:", peppaScore);
console.log("Updated Level:", peppaLevel);

# %% [markdown]
# ## Hack 2: JavaScript - Variable Declaration, Assignment, and Operators
# Declare variables for Peppa and George's scores using good JavaScript naming conventions. Assign initial values, then use operators to update both scores (e.g., Peppa gets 15 points, George loses 5 points). Print both scores.

# %%
# Q1 (Exponents)
# A cube has a side length of 4 units. What is its volume?
side_length = 4
volume = side_length ** 3
print("The volume of the cube is:", volume, "cubic units")

# Q2 (PEMDAS)
# Evaluate the expression: (12+8)/2 + (3^2)
# Note: In Python, ^ is bitwise XOR, so we use ** for exponentiation

result = (12 + 8) / 2 + (3 ** 2)
print("The result of the expression is:", result)

# Q3 (Algorithm)
# Define variables and perform operations on them
a = 10
b = 5
c = 2

# Perform arithmetic operations
sum_result = a + b
product_result = b * c
difference_result = a - c
division_result = a / b
power_result = b ** c

# Display the results
print("Sum:", sum_result)
print("Product:", product_result)
print("Difference:", difference_result)
print("Division:", division_result)
print("Power:", power_result)

## Hack 1: JavaScript - Variable Assignment, Naming, and Operators
# %%javascript
// Create variables for Peppa's name, score, and level
let peppaName = "Peppa";
let peppaScore = 0;
let peppaLevel = 1;

// Update score and level using operators
peppaScore += 10; // add 10 to score
peppaLevel *= 2;  // multiply level by 2

// Print results
console.log("Name:", peppaName);
console.log("Updated Score:", peppaScore);
console.log("Updated Level:", peppaLevel);

## Hack 2: JavaScript - Variable Declaration, Assignment, and Operators
# %%javascript
// Declare variables for Peppa and George's scores
let peppaScore2 = 20;
let georgeScore = 30;

// Update scores using operators
peppaScore2 += 15; // Peppa gets 15 points
georgeScore -= 5;  // George loses 5 points

// Print both scores
console.log("Peppa's Updated Score:", peppaScore2);
console.log("George's Updated Score:", georgeScore);

# %% [markdown]
# ## Hack 3: JavaScript - Multiple Assignment and Math Operators
# Peppa and George both start at level 1. Use a single line to assign both their levels to 5. Then, calculate a combined score by multiplying their levels together and multiplying by 10. Print all results.

# %%
# Q1 (Exponents)
# A cube has a side length of 4 units. What is its volume?
side_length = 4
volume = side_length ** 3
print("The volume of the cube is:", volume, "cubic units")

# Q2 (PEMDAS)
# Evaluate the expression: (12+8)/2 + (3^2)
# Note: In Python, ^ is bitwise XOR, so we use ** for exponentiation

result = (12 + 8) / 2 + (3 ** 2)
print("The result of the expression is:", result)

# Q3 (Algorithm)
# Define variables and perform operations on them
a = 10
b = 5
c = 2

# Perform arithmetic operations
sum_result = a + b
product_result = b * c
difference_result = a - c
division_result = a / b
power_result = b ** c

# Display the results
print("Sum:", sum_result)
print("Product:", product_result)
print("Difference:", difference_result)
print("Division:", division_result)
print("Power:", power_result)

## Hack 1: JavaScript - Variable Assignment, Naming, and Operators
# %%javascript
// Create variables for Peppa's name, score, and level
let peppaName = "Peppa";
let peppaScore = 0;
let peppaLevel = 1;

// Update score and level using operators
peppaScore += 10; // add 10 to score
peppaLevel *= 2;  // multiply level by 2

// Print results
console.log("Name:", peppaName);
console.log("Updated Score:", peppaScore);
console.log("Updated Level:", peppaLevel);

## Hack 2: JavaScript - Variable Declaration, Assignment, and Operators
# %%javascript
// Declare variables for Peppa and George's scores
let peppaScore2 = 20;
let georgeScore = 30;

// Update scores using operators
peppaScore2 += 15; // Peppa gets 15 points
georgeScore -= 5;  // George loses 5 points

// Print both scores
console.log("Peppa's Updated Score:", peppaScore2);
console.log("George's Updated Score:", georgeScore);

## Hack 3: JavaScript - Multiple Assignment and Math Operators
# %%javascript
// let peppaLevel = 1, georgeLevel = 1;
let peppaLevel3 = 1, georgeLevel3 = 1;

// Assign both levels to 5 in one line
peppaLevel3 = georgeLevel3 = 5;

// Calculate combinedScore = peppaLevel * georgeLevel * 10;
let combinedScore = peppaLevel3 * georgeLevel3 * 10;

// Print all results
console.log("Peppa's Level:", peppaLevel3);
console.log("George's Level:", georgeLevel3);
console.log("Combined Score:", combinedScore);
